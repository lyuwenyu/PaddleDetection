# %%
import ppdet
from ppdet.core.workspace import load_config, merge_config
from ppdet.core.workspace import create
# Out:
# Warning: import ppdet from source directory without installing, run 'python setup.py install' to install ppdet firstly

# %%
cfg = load_config('./configs/htc/htc_r50_fpn_1x_coco.yml')

# %%
model = create(cfg.architecture)

# %%
model.bbox_head.bbox_loss

# %%
cfg
# Out:
# {'ImageFolder': {},
#  'CommonDataset': {},
#  'TrainDataset': <ppdet.data.source.coco.COCODataSet at 0x7f93f819cb50>,
#  'EvalMOTDataset': {},
#  'TestMOTDataset': {},
#  'EvalDataset': <ppdet.data.source.coco.COCODataSet at 0x7f93f81811c0>,
#  'TestDataset': <ppdet.data.source.dataset.ImageFolder at 0x7f93f8181190>,
#  'COCODataSet': {},
#  'VOCDataSet': {},
#  'WIDERFaceDataSet': {},
#  'KeypointBottomUpCocoDataset': {},
#  'KeypointBottomUpCrowdPoseDataset': {},
#  'KeypointTopDownCocoDataset': {},
#  'KeypointTopDownMPIIDataset': {},
#  'MOTDataSet': {},
#  'MCMOTDataSet': {},
#  'MOTImageFolder': {},
#  'SniperCOCODataSet': {},
#  'VGG': {},
#  'ResNet': {'depth': 50,
#   'norm_type': 'bn',
#   'freeze_at': 0,
#   'return_idx': [0, 1, 2, 3],
#   'num_stages': 4},
#  'Res5Head': {},
#  'DarkNet': {},
#  'MobileNet': {},
#  'MobileNetV3': {},
#  'HRNet': {},
#  'AnchorGeneratorSSD': {},
#  'RCNNBox': {'prior_box_var': [30.0, 30.0, 15.0, 15.0]},
#  'MultiClassNMS': {'keep_top_k': 100,
#   'score_threshold': 0.001,
#   'nms_threshold': 0.5},
#  'MatrixNMS': {},
#  'YOLOBox': {},
#  'SSDBox': {},
#  'FCOSBox': {},
#  'TTFBox': {},
#  'JDEBox': {},
#  'MaskMatrixNMS': {},
#  'ConvMixer': {},
#  'LiteHRNet': {},
#  'BlazeNet': {},
#  'GhostNet': {},
#  'SENet': {},
#  'SERes5Head': {},
#  'Res2Net': {},
#  'Res2NetC5': {},
#  'DLA': {},
#  'ShuffleNetV2': {},
#  'SwinTransformer': {},
#  'LCNet': {},
#  'HarDNet': {},
#  'ESNet': {},
#  'CSPResNet': {},
#  'CSPDarkNet': {},
#  'FPN': {'out_channel': 256},
#  'YOLOv3FPN': {},
#  'PPYOLOFPN': {},
#  'PPYOLOTinyFPN': {},
#  'PPYOLOPAN': {},
#  'YOLOCSPPAN': {},
#  'HRFPN': {},
#  'TTFFPN': {},
#  'CenterNetDLAFPN': {},
#  'CenterNetHarDNetFPN': {},
#  'BiFPN': {},
#  'CSPPAN': {},
#  'ESPAN': {},
#  'LCPAN': {},
#  'CustomCSPPAN': {},
#  'BlazeNeck': {},
#  'AnchorGenerator': {},
#  'RetinaAnchorGenerator': {},
#  'RPNTargetAssign': {},
#  'BBoxAssigner': {'batch_size_per_im': 512,
#   'bg_thresh': 0.5,
#   'fg_thresh': 0.5,
#   'fg_fraction': 0.25,
#   'cascade_iou': [0.5, 0.6, 0.7],
#   'use_random': True},
#  'BBoxLibraAssigner': {},
#  'MaskAssigner': {'mask_resolution': 28},
#  'RBoxAssigner': {},
#  'ProposalGenerator': {},
#  'RPNHead': {'anchor_generator': {'aspect_ratios': [0.5, 1.0, 2.0],
#    'anchor_sizes': [[32], [64], [128], [256], [512]],
#    'strides': [4, 8, 16, 32, 64]},
#   'rpn_target_assign': {'batch_size_per_im': 256,
#    'fg_fraction': 0.5,
#    'negative_overlap': 0.3,
#    'positive_overlap': 0.7,
#    'use_random': True},
#   'train_proposal': {'min_size': 0.0,
#    'nms_thresh': 0.7,
#    'pre_nms_top_n': 2000,
#    'post_nms_top_n': 2000,
#    'topk_after_collect': True},
#   'test_proposal': {'min_size': 0.0,
#    'nms_thresh': 0.7,
#    'pre_nms_top_n': 1000,
#    'post_nms_top_n': 1000},
#   'use_smooth_l1_loss': True,
#   'smooth_l1_loss_beta_nume': 1.0,
#   'smooth_l1_loss_beta_deno': 9.0},
#  'RoIAlign': {},
#  'TwoFCHead': {},
#  'XConvNormHead': {},
#  'BBoxHead': {},
#  'MaskFeat': {'num_convs': 4, 'out_channel': 256},
#  'MaskHead': {},
#  'YOLOv3Loss': {},
#  'IouLoss': {},
#  'GIoULoss': {},
#  'DIouLoss': {},
#  'IouAwareLoss': {},
#  'SSDLoss': {},
#  'FCOSLoss': {},
#  'SOLOv2Loss': {},
#  'CTFocalLoss': {},
#  'KeyPointMSELoss': {},
#  'HrHRNetLoss': {},
#  'JDEDetectionLoss': {},
#  'JDEEmbeddingLoss': {},
#  'JDELoss': {},
#  'FairMOTLoss': {},
#  'QualityFocalLoss': {},
#  'DistributionFocalLoss': {},
#  'PositionEmbedding': {},
#  'DETRTransformer': {},
#  'HungarianMatcher': {},
#  'DeformableTransformer': {},
#  'DETRLoss': {},
#  'SparseRCNNLoss': {},
#  'FocalLoss': {},
#  'SmoothL1Loss': {},
#  'TaskAlignedAssigner': {},
#  'ATSSAssigner': {},
#  'VarifocalLoss': {},
#  'SimOTAAssigner': {},
#  'MaxIoUAssigner': {},
#  'YOLOv3Head': {},
#  'YOLOXHead': {},
#  'SSDHead': {},
#  'FCOSFeat': {},
#  'FCOSHead': {},
#  'SOLOv2MaskHead': {},
#  'SOLOv2Head': {},
#  'HMHead': {},
#  'WHHead': {},
#  'TTFHead': {},
#  'CascadeTwoFCHead': {},
#  'CascadeXConvNormHead': {},
#  'CascadeHead': {},
#  'FaceHead': {},
#  'S2ANetHead': {},
#  'HrHRNetHead': {},
#  'CenterNetHead': {},
#  'DGQP': {},
#  'GFLHead': {},
#  'OTAHead': {},
#  'OTAVFLHead': {},
#  'PicoFeat': {},
#  'PicoHead': {},
#  'PicoHeadV2': {},
#  'DETRHead': {},
#  'DeformableDETRHead': {},
#  'SparseRCNNHead': {},
#  'TOODHead': {},
#  'RetinaFeat': {},
#  'RetinaHead': {},
#  'PPYOLOEHead': {},
#  'HybridTaskCascadeTwoFCHead': {'out_channel': 1024},
#  'HybridTaskCascadeXConvNormHead': {},
#  'HybridTaskCascadeHead': {'head': 'HybridTaskCascadeTwoFCHead',
#   'roi_extractor': {'resolution': 7,
#    'sampling_ratio': 0,
#    'aligned': True,
#    'spatial_scale': [0.25, 0.125, 0.0625, 0.03125, 0.015625]},
#   'semantic_roi_extractor': {'resolution': 14,
#    'sampling_ratio': 0,
#    'aligned': True},
#   'bbox_assigner': 'BBoxAssigner',
#   'mask_head': 'HybridTaskMaskHead'},
#  'HybridTaskMaskFeatSub': {},
#  'HybridTaskMaskFeat': {},
#  'HybridTaskMaskHead': {'head': 'HybridTaskMaskFeat',
#   'roi_extractor': {'resolution': 14, 'sampling_ratio': 0, 'aligned': True},
#   'semantic_roi_extractor': {'resolution': 14,
#    'sampling_ratio': 0,
#    'aligned': True},
#   'mask_assigner': 'MaskAssigner',
#   'share_bbox_feat': False},
#  'FusedSemanticHead': {'semantic_num_class': 183, 'loss_weight': 0.2},
#  'BBoxPostProcess': {'decode': {'name': 'RCNNBox',
#    'prior_box_var': [30.0, 30.0, 15.0, 15.0]},
#   'nms': {'name': 'MultiClassNMS',
#    'keep_top_k': 100,
#    'score_threshold': 0.001,
#    'nms_threshold': 0.5}},
#  'MaskPostProcess': {'binary_thresh': 0.5},
#  'FCOSPostProcess': {},
#  'S2ANetBBoxPostProcess': {},
#  'JDEBBoxPostProcess': {},
#  'CenterNetPostProcess': {},
#  'DETRBBoxPostProcess': {},
#  'SparsePostProcess': {},
#  'BaseArch': {},
#  'FasterRCNN': {},
#  'MaskRCNN': {},
#  'YOLOv3': {},
#  'CascadeRCNN': {},
#  'SSD': {},
#  'FCOS': {},
#  'SOLOv2': {},
#  'TTFNet': {},
#  'S2ANet': {},
#  'HigherHRNet': {},
#  'HrHRNetPostProcess': {},
#  'TopDownHRNet': {},
#  'JDE': {},
#  'KalmanFilter': {},
#  'BaseTrack': {},
#  'STrack': {},
#  'Track': {},
#  'JDETracker': {},
#  'DeepSORTTracker': {},
#  'DeepSORT': {},
#  'FairMOT': {},
#  'CenterNet': {},
#  'GFL': {},
#  'PicoDet': {},
#  'DETR': {},
#  'SparseRCNN': {},
#  'TOOD': {},
#  'RetinaNet': {},
#  'ByteTrack': {},
#  'YOLOX': {},
#  'HybridTaskCascade': {'backbone': 'ResNet',
#   'neck': 'FPN',
#   'rpn_head': 'RPNHead',
#   'bbox_head': 'HybridTaskCascadeHead',
#   'fused_semantic_head': None,
#   'bbox_post_process': 'BBoxPostProcess',
#   'mask_post_process': 'MaskPostProcess'},
#  'BlazeFace': {},
#  'JDEEmbeddingHead': {},
#  'FairMOTEmbeddingHead': {},
#  'PCBPyramid': {},
#  'PPLCNetEmbedding': {},
#  'ResNetEmbedding': {},
#  'TrainReader': {'sample_transforms': [{'Decode': {}},
#    {'Resize': {'interp': 1, 'target_size': [800, 1333], 'keep_ratio': True}},
#    {'RandomFlip': {'prob': 0.5}},
#    {'NormalizeImage': {'is_scale': True,
#      'mean': [0.485, 0.456, 0.406],
#      'std': [0.229, 0.224, 0.225]}},
#    {'Permute': {}}],
#   'batch_transforms': [{'PadBatch': {'pad_to_stride': 32}},
#    {'SegRescale': {'scale_factor': 0.125}}],
#   'batch_size': 1,
#   'shuffle': True,
#   'drop_last': True,
#   'collate_batch': False},
#  'EvalReader': {'sample_transforms': [{'Decode': {}},
#    {'Resize': {'interp': 1, 'target_size': [800, 1333], 'keep_ratio': True}},
#    {'NormalizeImage': {'is_scale': True,
#      'mean': [0.485, 0.456, 0.406],
#      'std': [0.229, 0.224, 0.225]}},
#    {'Permute': {}}],
#   'batch_transforms': [{'PadBatch': {'pad_to_stride': 32}}],
#   'batch_size': 1,
#   'shuffle': False,
#   'drop_last': False},
#  'TestReader': {'sample_transforms': [{'Decode': {}},
#    {'Resize': {'interp': 1, 'target_size': [800, 1333], 'keep_ratio': True}},
#    {'NormalizeImage': {'is_scale': True,
#      'mean': [0.485, 0.456, 0.406],
#      'std': [0.229, 0.224, 0.225]}},
#    {'Permute': {}}],
#   'batch_transforms': [{'PadBatch': {'pad_to_stride': 32}}],
#   'batch_size': 1,
#   'shuffle': False,
#   'drop_last': False},
#  'EvalMOTReader': {},
#  'TestMOTReader': {},
#  'LearningRate': {'base_lr': 0.02,
#   'schedulers': [<ppdet.optimizer.optimizer.PiecewiseDecay at 0x7f93f8181370>,
#    <ppdet.optimizer.optimizer.LinearWarmup at 0x7f93f81813d0>]},
#  'OptimizerBuilder': {'optimizer': {'momentum': 0.9, 'type': 'Momentum'},
#   'regularizer': {'factor': 0.0001, 'type': 'L2'}},
#  'Pruner': {},
#  'PrunerQAT': {},
#  'QAT': {},
#  'PTQ': {},
#  'DistillYOLOv3Loss': {},
#  'UnstructuredPruner': {},
#  'OFA': {},
#  'metric': 'COCO',
#  'num_classes': 80,
#  'use_gpu': True,
#  'use_xpu': False,
#  'log_iter': 20,
#  'save_dir': 'output',
#  'snapshot_epoch': 1,
#  'print_flops': False,
#  'export': {'post_process': True,
#   'nms': True,
#   'benchmark': False,
#   'fuse_conv_bn': False},
#  'epoch': 12,
#  'worker_num': 4,
#  'architecture': 'HybridTaskCascade',
#  'pretrain_weights': 'https://paddledet.bj.bcebos.com/models/pretrained/ResNet50_cos_pretrained.pdparams',
#  'weights': 'output/htc_r50_fpn_1x_coco/model_final',
#  'filename': 'htc_r50_fpn_1x_coco'}
